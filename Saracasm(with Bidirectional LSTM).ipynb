# %%
import numpy as np
import json
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
vocab_size = 1000
embedding_dim = 16
max_length = 120
trunc_type='post'
padding_type='post'
oov_tok = "<OOV>"
training_size = 20000


with open("Datasets/sarcasm.json", 'r') as f:
    datastore = json.load(f)


sentences = []
labels = []
urls = []
for item in datastore:
    sentences.append(item['headline'])
    labels.append(item['is_sarcastic'])

training_sentences = sentences[0:training_size]
testing_sentences = sentences[training_size:]
training_labels = labels[0:training_size]
testing_labels = labels[training_size:]

tokenizer = Tokenizer(num_words=vocab_size, oov_token=oov_tok)
tokenizer.fit_on_texts(training_sentences)

word_index = tokenizer.word_index

training_sequences = tokenizer.texts_to_sequences(training_sentences)
training_padded = pad_sequences(training_sequences, maxlen=max_length, padding=padding_type, truncating=trunc_type)

testing_sequences = tokenizer.texts_to_sequences(testing_sentences)
testing_padded = pad_sequences(testing_sequences, maxlen=max_length, padding=padding_type, truncating=trunc_type)

model = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_length),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32)),
    tf.keras.layers.Dense(24, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
model.summary()

num_epochs = 50
training_padded = np.array(training_padded)
training_labels = np.array(training_labels)
testing_padded = np.array(testing_padded)
testing_labels = np.array(testing_labels)
history = model.fit(training_padded, training_labels, epochs=num_epochs, validation_data=(testing_padded, testing_labels), verbose=1)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 120, 16)           16000
# _________________________________________________________________
# bidirectional (Bidirectional (None, 64)                12544
# _________________________________________________________________
# dense (Dense)                (None, 24)                1560
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 25
# =================================================================
# Total params: 30,129
# Trainable params: 30,129
# Non-trainable params: 0
# _________________________________________________________________
# Train on 20000 samples, validate on 6709 samples
# Epoch 1/50
# 20000/20000 [==============================] - 16s 803us/sample - loss: 0.4560 - accuracy: 0.7694 - val_loss: 0.3872 - val_accuracy: 0.8216
# Epoch 2/50
# 20000/20000 [==============================] - 12s 617us/sample - loss: 0.3591 - accuracy: 0.8339 - val_loss: 0.3771 - val_accuracy: 0.8256
# Epoch 3/50
# 20000/20000 [==============================] - 12s 613us/sample - loss: 0.3381 - accuracy: 0.8479 - val_loss: 0.3791 - val_accuracy: 0.8259
# Epoch 4/50
# 20000/20000 [==============================] - 12s 617us/sample - loss: 0.3194 - accuracy: 0.8563 - val_loss: 0.3763 - val_accuracy: 0.8280
# Epoch 5/50
# 20000/20000 [==============================] - 12s 618us/sample - loss: 0.3046 - accuracy: 0.8631 - val_loss: 0.3786 - val_accuracy: 0.8305
# Epoch 6/50
# 20000/20000 [==============================] - 12s 616us/sample - loss: 0.2936 - accuracy: 0.8706 - val_loss: 0.3771 - val_accuracy: 0.8341
# Epoch 7/50
# 20000/20000 [==============================] - 12s 606us/sample - loss: 0.2856 - accuracy: 0.8743 - val_loss: 0.3905 - val_accuracy: 0.8317
# Epoch 8/50
# 20000/20000 [==============================] - 12s 616us/sample - loss: 0.2761 - accuracy: 0.8784 - val_loss: 0.3908 - val_accuracy: 0.8313
# Epoch 9/50
# 20000/20000 [==============================] - 12s 615us/sample - loss: 0.2694 - accuracy: 0.8813 - val_loss: 0.3939 - val_accuracy: 0.8320
# Epoch 10/50
# 20000/20000 [==============================] - 12s 604us/sample - loss: 0.2622 - accuracy: 0.8854 - val_loss: 0.3903 - val_accuracy: 0.8344
# Epoch 11/50
# 20000/20000 [==============================] - 12s 618us/sample - loss: 0.2528 - accuracy: 0.8898 - val_loss: 0.4123 - val_accuracy: 0.8247
# Epoch 12/50
# 20000/20000 [==============================] - 12s 613us/sample - loss: 0.2458 - accuracy: 0.8949 - val_loss: 0.4134 - val_accuracy: 0.8277
# Epoch 13/50
# 20000/20000 [==============================] - 12s 600us/sample - loss: 0.2384 - accuracy: 0.8965 - val_loss: 0.4174 - val_accuracy: 0.8258
# Epoch 14/50
# 20000/20000 [==============================] - 13s 663us/sample - loss: 0.2343 - accuracy: 0.8988 - val_loss: 0.4938 - val_accuracy: 0.8186
# Epoch 15/50
# 20000/20000 [==============================] - 13s 632us/sample - loss: 0.2277 - accuracy: 0.9018 - val_loss: 0.4418 - val_accuracy: 0.8196
# Epoch 16/50
# 20000/20000 [==============================] - 13s 625us/sample - loss: 0.2215 - accuracy: 0.9059 - val_loss: 0.4604 - val_accuracy: 0.8211
# Epoch 17/50
# 20000/20000 [==============================] - 13s 626us/sample - loss: 0.2142 - accuracy: 0.9099 - val_loss: 0.4746 - val_accuracy: 0.8235
# Epoch 18/50
# 20000/20000 [==============================] - 12s 621us/sample - loss: 0.2085 - accuracy: 0.9147 - val_loss: 0.5125 - val_accuracy: 0.8207
# Epoch 19/50
# 20000/20000 [==============================] - 12s 593us/sample - loss: 0.2012 - accuracy: 0.9173 - val_loss: 0.5062 - val_accuracy: 0.8179
# Epoch 20/50
# 20000/20000 [==============================] - 13s 625us/sample - loss: 0.1943 - accuracy: 0.9209 - val_loss: 0.5380 - val_accuracy: 0.8147
# Epoch 21/50
# 20000/20000 [==============================] - 12s 605us/sample - loss: 0.1882 - accuracy: 0.9233 - val_loss: 0.5402 - val_accuracy: 0.8132
# Epoch 22/50
# 20000/20000 [==============================] - 12s 612us/sample - loss: 0.1823 - accuracy: 0.9257 - val_loss: 0.5159 - val_accuracy: 0.8138
# Epoch 23/50
# 20000/20000 [==============================] - 12s 605us/sample - loss: 0.1762 - accuracy: 0.9283 - val_loss: 0.6287 - val_accuracy: 0.8117
# Epoch 24/50
# 20000/20000 [==============================] - 12s 600us/sample - loss: 0.1674 - accuracy: 0.9317 - val_loss: 0.6421 - val_accuracy: 0.8109
# Epoch 25/50
# 20000/20000 [==============================] - 12s 608us/sample - loss: 0.1629 - accuracy: 0.9345 - val_loss: 0.5889 - val_accuracy: 0.8103
# Epoch 26/50
# 20000/20000 [==============================] - 12s 613us/sample - loss: 0.1544 - accuracy: 0.9391 - val_loss: 0.6921 - val_accuracy: 0.8091
# Epoch 27/50
# 20000/20000 [==============================] - 12s 622us/sample - loss: 0.1517 - accuracy: 0.9391 - val_loss: 0.6557 - val_accuracy: 0.8056
# Epoch 28/50
# 20000/20000 [==============================] - 12s 620us/sample - loss: 0.1455 - accuracy: 0.9417 - val_loss: 0.7172 - val_accuracy: 0.8062
# Epoch 29/50
# 20000/20000 [==============================] - 12s 614us/sample - loss: 0.1376 - accuracy: 0.9466 - val_loss: 0.7605 - val_accuracy: 0.7985
# Epoch 30/50
# 20000/20000 [==============================] - 12s 615us/sample - loss: 0.1363 - accuracy: 0.9452 - val_loss: 0.7967 - val_accuracy: 0.8013
# Epoch 31/50
# 20000/20000 [==============================] - 12s 623us/sample - loss: 0.1305 - accuracy: 0.9490 - val_loss: 0.7834 - val_accuracy: 0.7980
# Epoch 32/50
# 20000/20000 [==============================] - 12s 603us/sample - loss: 0.1256 - accuracy: 0.9495 - val_loss: 0.9194 - val_accuracy: 0.8025
# Epoch 33/50
# 20000/20000 [==============================] - 12s 598us/sample - loss: 0.1211 - accuracy: 0.9514 - val_loss: 0.8458 - val_accuracy: 0.8012
# Epoch 34/50
# 20000/20000 [==============================] - 12s 599us/sample - loss: 0.1136 - accuracy: 0.9552 - val_loss: 0.9381 - val_accuracy: 0.8025
# Epoch 35/50
# 20000/20000 [==============================] - 12s 612us/sample - loss: 0.1106 - accuracy: 0.9566 - val_loss: 0.9255 - val_accuracy: 0.8032
# Epoch 36/50
# 20000/20000 [==============================] - 12s 619us/sample - loss: 0.1094 - accuracy: 0.9564 - val_loss: 0.9818 - val_accuracy: 0.7973
# Epoch 37/50
# 20000/20000 [==============================] - 12s 603us/sample - loss: 0.1006 - accuracy: 0.9603 - val_loss: 1.0865 - val_accuracy: 0.7992
# Epoch 38/50
# 20000/20000 [==============================] - 12s 613us/sample - loss: 0.0967 - accuracy: 0.9610 - val_loss: 1.0888 - val_accuracy: 0.7933
# Epoch 39/50
# 20000/20000 [==============================] - 13s 625us/sample - loss: 0.0934 - accuracy: 0.9621 - val_loss: 1.1765 - val_accuracy: 0.8000
# Epoch 40/50
# 20000/20000 [==============================] - 12s 622us/sample - loss: 0.0886 - accuracy: 0.9635 - val_loss: 1.2519 - val_accuracy: 0.7919
# Epoch 41/50
# 20000/20000 [==============================] - 12s 623us/sample - loss: 0.0871 - accuracy: 0.9635 - val_loss: 1.2747 - val_accuracy: 0.7952
# Epoch 42/50
# 20000/20000 [==============================] - 12s 602us/sample - loss: 0.0851 - accuracy: 0.9659 - val_loss: 1.2533 - val_accuracy: 0.7945
# Epoch 43/50
# 20000/20000 [==============================] - 12s 597us/sample - loss: 0.0808 - accuracy: 0.9671 - val_loss: 1.3038 - val_accuracy: 0.7933
# Epoch 44/50
# 20000/20000 [==============================] - 12s 601us/sample - loss: 0.0786 - accuracy: 0.9678 - val_loss: 1.2926 - val_accuracy: 0.7980
# Epoch 45/50
# 20000/20000 [==============================] - 12s 621us/sample - loss: 0.0741 - accuracy: 0.9696 - val_loss: 1.3484 - val_accuracy: 0.7930
# Epoch 46/50
# 20000/20000 [==============================] - 12s 619us/sample - loss: 0.0675 - accuracy: 0.9722 - val_loss: 1.4620 - val_accuracy: 0.7964
# Epoch 47/50
# 20000/20000 [==============================] - 12s 618us/sample - loss: 0.0706 - accuracy: 0.9696 - val_loss: 1.4572 - val_accuracy: 0.7940
# Epoch 48/50
# 20000/20000 [==============================] - 12s 618us/sample - loss: 0.0653 - accuracy: 0.9726 - val_loss: 1.5401 - val_accuracy: 0.7949
# Epoch 49/50
# 20000/20000 [==============================] - 12s 609us/sample - loss: 0.0675 - accuracy: 0.9718 - val_loss: 1.4836 - val_accuracy: 0.7949
# Epoch 50/50
# 20000/20000 [==============================] - 12s 610us/sample - loss: 0.0607 - accuracy: 0.9740 - val_loss: 1.5677 - val_accuracy: 0.7904

# %%
import matplotlib.pyplot as plt


def plot_graphs(history, string):
    plt.plot(history.history[string])
    plt.plot(history.history['val_'+string])
    plt.xlabel("Epochs")
    plt.ylabel(string)
    plt.legend([string, 'val_'+string])
    plt.show()

plot_graphs(history, 'accuracy')
plot_graphs(history, 'loss')
